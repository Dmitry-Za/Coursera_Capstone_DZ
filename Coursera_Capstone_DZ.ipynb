# %% [markdown]
# This is a Jupiter Notebook for Coursera Capstone Project

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# First install all libraries. Probably, some are not needed for this particular  task, but nevertheless

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print("Installing GeoPy...\n")
# !pip -q install geopy
print("GeoPy has been successfully installed!\n")

print("Installing Folium...\n")
# !pip -q install folium
print("Folium has been successfully installed!\n")

# !pip install requests

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library


print('Libraries imported.')
# Out:
# Installing GeoPy...
#
# GeoPy has been successfully installed!
#
# Installing Folium...
#
# Folium has been successfully installed!
#
# ...
# Libraries imported.

# %% [markdown]
# Read the dataframe using pandas read_html

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M") [0]
df
# Out:
#                                                     0  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# ...

# %% [markdown]
# The format is not convenient. We will transform it into 3 separate lists of 1. postal code, 2. borough and 3. neighborhood (for the last one we will also replace "/" with ","), and on the next step we will combine them into one dataframe.

# %%
i=0
j=0

list_all=[]
list_ind=[]
list_bor=[]
list_nei=[]

i=0

while (i<=19):
    j=0
    
    while (j<=8):
        list_all.append(df.iloc[i,j])
        list_ind.append(str(df.iloc[i,j])[0:3])
        list_bor.append(str(df.iloc[i,j])[3:str(df.iloc[i,j]).find("(")])
        list_nei.append(str(df.iloc[i,j])[str(df.iloc[i,j]).find("(")+1:str(df.iloc[i,j]).find(")")])
        j=j+1
    i=i+1

list_nei1 = [sub.replace('/', ',') for sub in list_nei]

# %% [markdown]
# Here we put 3 lists together into 1 dataframe:

# %%
#d = {'PostalCode': [list_ind], 'Borough': [list_bor],'Neighborhood':[list_nei]}
df = pd.DataFrame(list(zip(list_ind, list_bor,list_nei1)), 
               columns =['PostalCode', 'Borough','Neighborhood']) 
df
# Out:
#     PostalCode                                            Borough  \
# 0          M1A                                        Not assigne
# 1          M2A                                        Not assigne
# 2          M3A                                         North York
# 3          M4A                                         North York
# 4          M5A                                   Downtown Toronto
# 5          M6A                                         North York
# 6          M7A        Queen's Park / Ontario Provincial Governmen
# 7          M8A                                        Not assigne
# 8          M9A                                          Etobicoke
# 9          M1B                                        Scarborough
# 10         M2B                                        Not assigne
# 11         M3B                                         North York
# 12         M4B                                          East York
# ...

# %% [markdown]
# Now we remove Boroughs that have no assigned values, and then remove the lines where 2 Boroughs are combined

# %%
df_filt1=df[df.Borough!="Not assigne"]
df_filt1
# Out:
#     PostalCode                                            Borough  \
# 2          M3A                                         North York
# 3          M4A                                         North York
# 4          M5A                                   Downtown Toronto
# 5          M6A                                         North York
# 6          M7A        Queen's Park / Ontario Provincial Governmen
# 8          M9A                                          Etobicoke
# 9          M1B                                        Scarborough
# 11         M3B                                         North York
# 12         M4B                                          East York
# 13         M5B                                   Downtown Toronto
# 14         M6B                                         North York
# 17         M9B                                          Etobicoke
# 18         M1C                                        Scarborough
# ...

# %%
df_filt1=df_filt1[df_filt1.Borough.str.len()<40]
df_filt1
# Out:
#     PostalCode                Borough  \
# 2          M3A             North York
# 3          M4A             North York
# 4          M5A       Downtown Toronto
# 5          M6A             North York
# 8          M9A              Etobicoke
# 9          M1B            Scarborough
# 11         M3B             North York
# 12         M4B              East York
# 13         M5B       Downtown Toronto
# 14         M6B             North York
# 17         M9B              Etobicoke
# 18         M1C            Scarborough
# 20         M3C             North York
# 21         M4C              East York
# 22         M5C       Downtown Toronto
# 23         M6C                   York
# 26         M9C              Etobicoke
# 27         M1E            Scarborough
# 30         M4E           East Toronto
# 31         M5E       Downtown Toronto
# 32         M6E                   York
# 36         M1G            Scarborough
# 39         M4G              East York
# ...

# %% [markdown]
# And finally we reset the index

# %%
df_filt1.reset_index(inplace = True, drop = True) 
df_filt1
# Out:
#    PostalCode                Borough  \
# 0         M3A             North York
# 1         M4A             North York
# 2         M5A       Downtown Toronto
# 3         M6A             North York
# 4         M9A              Etobicoke
# 5         M1B            Scarborough
# 6         M3B             North York
# 7         M4B              East York
# 8         M5B       Downtown Toronto
# 9         M6B             North York
# 10        M9B              Etobicoke
# 11        M1C            Scarborough
# 12        M3C             North York
# 13        M4C              East York
# 14        M5C       Downtown Toronto
# 15        M6C                   York
# 16        M9C              Etobicoke
# 17        M1E            Scarborough
# 18        M4E           East Toronto
# 19        M5E       Downtown Toronto
# 20        M6E                   York
# 21        M1G            Scarborough
# 22        M4G              East York
# 23        M5G       Downtown Toronto
# ...

# %%
df_filt1.shape
# Out:
# (99, 3)

# %% [markdown]
# ## +++++  PART 2  ++++

# %% [markdown]
# Read csv file with data coordinates

# %%
df_ll = pd.read_csv("http://cocl.us/Geospatial_data") 
df_ll
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
Rename Postal Code column to match the column name in the previous dataframe

# %%
df_ll.rename(columns={'Postal Code': 'PostalCode'}, inplace=True)
df_ll
# Out:
#     PostalCode   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# 5          M1J  43.744734 -79.239476
# 6          M1K  43.727929 -79.262029
# 7          M1L  43.711112 -79.284577
# 8          M1M  43.716316 -79.239476
# 9          M1N  43.692657 -79.264848
# 10         M1P  43.757410 -79.273304
# 11         M1R  43.750072 -79.295849
# 12         M1S  43.794200 -79.262029
# 13         M1T  43.781638 -79.304302
# 14         M1V  43.815252 -79.284577
# 15         M1W  43.799525 -79.318389
# 16         M1X  43.836125 -79.205636
# 17         M2H  43.803762 -79.363452
# 18         M2J  43.778517 -79.346556
# 19         M2K  43.786947 -79.385975
# 20         M2L  43.757490 -79.374714
# 21         M2M  43.789053 -79.408493
# 22         M2N  43.770120 -79.408493
# 23         M2P  43.752758 -79.400049
# ...

# %%
And merge the dataframes:

# %%
df_tor = pd.merge(df_filt1,df_ll, on='PostalCode')
df_tor
# Out:
#    PostalCode                Borough  \
# 0         M3A             North York
# 1         M4A             North York
# 2         M5A       Downtown Toronto
# 3         M6A             North York
# 4         M9A              Etobicoke
# 5         M1B            Scarborough
# 6         M3B             North York
# 7         M4B              East York
# 8         M5B       Downtown Toronto
# 9         M6B             North York
# 10        M9B              Etobicoke
# 11        M1C            Scarborough
# 12        M3C             North York
# 13        M4C              East York
# 14        M5C       Downtown Toronto
# 15        M6C                   York
# 16        M9C              Etobicoke
# 17        M1E            Scarborough
# 18        M4E           East Toronto
# 19        M5E       Downtown Toronto
# 20        M6E                   York
# 21        M1G            Scarborough
# 22        M4G              East York
# 23        M5G       Downtown Toronto
# ...
